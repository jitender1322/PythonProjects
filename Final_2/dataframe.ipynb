# %%
import pandas as pd

# %%
df = pd.read_csv("library_transactions.csv")
df.head(20)
# Out:
#     Transaction ID        Date  User ID              Book Title      Genre  \
# 0                1  2024-11-23     1014            Harry Potter    Fantasy
# 1                2  2024-05-20     1031   To Kill a Mockingbird    Classic
# 2                3  2024-02-22     1086         Sherlock Holmes    Mystery
# 3                4  2024-10-06     1011       The Da Vinci Code    Mystery
# 4                5  2024-01-17     1003              The Hobbit    Fantasy
# 5                6  2024-04-29     1064       The Da Vinci Code    Mystery
# 6                7  2024-10-14     1025         Sherlock Holmes    Mystery
# 7                8  2024-12-25     1069     Pride and Prejudice    Romance
# 8                9  2024-08-17     1075  The Catcher in the Rye    Classic
# 9               10  2024-01-04     1097                    1984  Dystopian
# 10              11  2024-08-04     1043  The Catcher in the Rye    Classic
# ...

# %%
a=pd.to_datetime(df["Date"])
a.dt.month_name()
# Out:
# 0      November
# 1           May
# 2      February
# 3       October
# 4       January
#         ...
# 95      October
# 96       August
# 97    September
# 98     December
# 99          May
# Name: Date, Length: 100, dtype: object
